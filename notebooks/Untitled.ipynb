# %%
# systems
import os, sys

import pandas as pd
import numpy as np

#
sys.path.insert(0, '../src/')
from events import Events
from listing import *

# %%
e = Events()
e.update_manifest()
# Out:
# http://mailman.mit.edu/mailman/private/mitml/2015-October/000014.html
# http://mailman.mit.edu/mailman/private/mitml/2015-October/000015.html
# http://mailman.mit.edu/mailman/private/mitml/2015-October/000016.html
# http://mailman.mit.edu/mailman/private/mitml/2015-October/000017.html
# http://mailman.mit.edu/mailman/private/mitml/2015-October/000018.html
# http://mailman.mit.edu/mailman/private/mitml/2015-October/000019.html
# http://mailman.mit.edu/mailman/private/mitml/2015-November/000020.html
# http://mailman.mit.edu/mailman/private/mitml/2015-November/000021.html
# http://mailman.mit.edu/mailman/private/mitml/2015-November/000022.html
# http://mailman.mit.edu/mailman/private/mitml/2015-November/000023.html
# http://mailman.mit.edu/mailman/private/mitml/2015-November/000024.html
# http://mailman.mit.edu/mailman/private/mitml/2015-November/000025.html
# http://mailman.mit.edu/mailman/private/mitml/2015-November/000026.html
# ...

# %%
e.manifest[e.manifest['is_talk']].sort_values('event_id')
# Out:
#                                           description  \
# 0   http://mailman.mit.edu/mailman/private/mitml/2...
# 14  http://mailman.mit.edu/mailman/private/mitml/2...
# 22  http://mailman.mit.edu/mailman/private/mitml/2...
# 25  http://mailman.mit.edu/mailman/private/mitml/2...
# 26  http://mailman.mit.edu/mailman/private/mitml/2...
# 27  http://mailman.mit.edu/mailman/private/mitml/2...
# 29  http://mailman.mit.edu/mailman/private/mitml/2...
# 31  http://mailman.mit.edu/mailman/private/mitml/2...
# 32  http://mailman.mit.edu/mailman/private/mitml/2...
# 35  http://mailman.mit.edu/mailman/private/mitml/2...
# 36  http://mailman.mit.edu/mailman/private/mitml/2...
# 42  http://mailman.mit.edu/mailman/private/mitml/2...
# 45  http://mailman.mit.edu/mailman/private/mitml/2...
# 50  http://mailman.mit.edu/mailman/private/mitml/2...
# 51  http://mailman.mit.edu/mailman/private/mitml/2...
# 54  http://mailman.mit.edu/mailman/private/mitml/2...
# ...

# %%
e.manifest
# Out:
#                                           description  \
# 0   http://mailman.mit.edu/mailman/private/mitml/2...
# 1   http://mailman.mit.edu/mailman/private/mitml/2...
# 2   http://mailman.mit.edu/mailman/private/mitml/2...
# 3   http://mailman.mit.edu/mailman/private/mitml/2...
# 4   http://mailman.mit.edu/mailman/private/mitml/2...
# 5   http://mailman.mit.edu/mailman/private/mitml/2...
# 6   http://mailman.mit.edu/mailman/private/mitml/2...
# 7   http://mailman.mit.edu/mailman/private/mitml/2...
# 8   http://mailman.mit.edu/mailman/private/mitml/2...
# 9   http://mailman.mit.edu/mailman/private/mitml/2...
# 10  http://mailman.mit.edu/mailman/private/mitml/2...
# 11  http://mailman.mit.edu/mailman/private/mitml/2...
# 12  http://mailman.mit.edu/mailman/private/mitml/2...
# 13  http://mailman.mit.edu/mailman/private/mitml/2...
#
#                                               message event_id is_correction  \
# ...

# %%
e._save_manifest()
