# %%
# systems
import os, sys

import pandas as pd
import numpy as np

#
sys.path.insert(0, '../src/')
from events import Events
from listing import *

# %%
e = Events('bestudents', 'bestudents')
e.update_manifest()
# Out:
# 09:02:35 - Session: INFO - Event created: https://www.google.com/calendar/event?eid=NWxoa3MzcnZlNnBzNDBlYXRrZDd2OXQ4cDQgOHQwNTV1bDlybDc0NTE4bm1zNGUybDB0Y2NAZw
# 09:02:35 - Events: INFO - Added to manifest: http://mailman.mit.edu/mailman/private/bestudents/2007-May/000051.html
# 09:02:38 - Session: INFO - Event created: https://www.google.com/calendar/event?eid=aTRmcmM3dTU4OHRqNmtrZTAxbHV2cmI4c3MgOHQwNTV1bDlybDc0NTE4bm1zNGUybDB0Y2NAZw
# 09:02:38 - Events: INFO - Added to manifest: http://mailman.mit.edu/mailman/private/bestudents/2007-May/000053.html
# 09:02:41 - Session: INFO - Event created: https://www.google.com/calendar/event?eid=b3YwcWV0c2k2dTUwbmlsYnZyam5oYWRkdGcgOHQwNTV1bDlybDc0NTE4bm1zNGUybDB0Y2NAZw
# 09:02:41 - Events: INFO - Added to manifest: http://mailman.mit.edu/mailman/private/bestudents/2007-May/000054.html
# 09:02:42 - Session: INFO - Event created: https://www.google.com/calendar/event?eid=ODRsazlqZWFxYm9kZHBlZW9sYjRtb2NqZnMgOHQwNTV1bDlybDc0NTE4bm1zNGUybDB0Y2NAZw
# ...

# %%
Listing('bestudents', '000018.html').message
# Out:
# "The MIT Career Office and the Postdoctoral Advisory Council are sponsoring a\ntalk for students considering an academic career on May 8.\n\nPlease see the announcement below for more information.\n\n \n\nRachel Miller\n\nBE Board Academic Rep\n\n -------------------------------------\n\n\nFOR GRADUATE STUDENTS & POSTDOCS: Considering an Academic Career\n\n\nMay 08, 2007  12:00p-2:00p\n\n\nLearn more about the academic career path, from the author of Tomorrow's\nProfessor and the listserv by the same name [\nhttp://sll.stanford.edu/projects/tomprof/newtomprof/index.shtml ]. \n\nFor a bio of the speaker, see [\nhttp://sll.stanford.edu/projects/tomprof/newtomprof/reis.html ]. \n\nAlso see Richard Reis' academic career column, Catalyst, appearing in The\nChronicle of Higher Education on-line Career Network, \n\nat [ http://chronicle.com/jobs/archive/advicearch.htm#catalyst ].\n\n\nSpeaker:\n\nProf. Richard Reis, Executive Director, Alliance for Innovative\nManufacturing (AIM) at Stanfor
# ...

# %%
Listing('bestudents', '000019.html').message
# Out:
# "-------------------------------------\n\n\nFOR GRADUATE STUDENTS & POSTDOCS: Considering an Academic Career\n\n\nMay 08, 2007  12:00p-2:00p\n\n\nLearn more about the academic career path, from the author of Tomorrow's\nProfessor and the listserv by the same name [\nhttp://sll.stanford.edu/projects/tomprof/newtomprof/index.shtml ]. \n\nFor a bio of the speaker, see [\nhttp://sll.stanford.edu/projects/tomprof/newtomprof/reis.html ]. \n\nAlso see Richard Reis' academic career column, Catalyst, appearing in The\nChronicle of Higher Education on-line Career Network, \n\nat [ http://chronicle.com/jobs/archive/advicearch.htm#catalyst ].\n\n\nSpeaker:\n\nProf. Richard Reis, Executive Director, Alliance for Innovative\nManufacturing (AIM) at Stanford and Associate Director of Global Learning\nPartnerships, Stanford Learning Lab.\n\n\nLocation:\n\n10-250 \n\n\nSponsored by:\n\nGraduate Career Services\n\n\nAdmission:\n\nfree\nOpen to: interested students, faculty or postdocs from MIT or beyon
# ...

# %%
similarity = lambda a,b: SequenceMatcher(None, a, b).ratio()

# %%
e.manifest
# Out:
#                                           description  \
# 0   http://mailman.mit.edu/mailman/private/bestude...
# 1   http://mailman.mit.edu/mailman/private/bestude...
# 2   http://mailman.mit.edu/mailman/private/bestude...
# 3   http://mailman.mit.edu/mailman/private/bestude...
# 4   http://mailman.mit.edu/mailman/private/bestude...
# 5   http://mailman.mit.edu/mailman/private/bestude...
# 6   http://mailman.mit.edu/mailman/private/bestude...
# 7   http://mailman.mit.edu/mailman/private/bestude...
# 8   http://mailman.mit.edu/mailman/private/bestude...
# 9   http://mailman.mit.edu/mailman/private/bestude...
# 10  http://mailman.mit.edu/mailman/private/bestude...
# 11  http://mailman.mit.edu/mailman/private/bestude...
# 12  http://mailman.mit.edu/mailman/private/bestude...
# 13  http://mailman.mit.edu/mailman/private/bestude...
# 14  http://mailman.mit.edu/mailman/private/bestude...
# 15  http://mailman.mit.edu/mailman/private/bestude...
# ...
